# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import matplotlib.patches as patches
from shapely.geometry import Point, Polygon, LineString
from itertools import groupby
from matplotlib.lines import Line2D
from itertools import cycle, islice

# %%
m7 = 4
n7 = 1
cosalpha7 = (n7**2 + 4*m7*n7 + m7**2) / (2*(n7**2 + m7*n7 + m7**2))
alpha7 = math.acos(cosalpha7)
N7 = 4 * (n7**2 + m7*n7 + m7**2)/3
print('alpha=',np.degrees(alpha7),'N=',N7)
# Out:
# alpha= 38.21321070173819 N= 28.0

# %%
m1 = 2
n1 = 1
cosalpha1 = (n1**2 + 4*m1*n1 + m1**2) / (2*(n1**2 + m1*n1 + m1**2))
alpha1 = math.acos(cosalpha1)
N1 = 4 * (n1**2 + m1*n1 + m1**2)
print('alpha=',np.degrees(alpha1),'N=',N1)
# Out:
# alpha= 21.78678929826181 N= 28

# %%
m2 = 4
n2 = 1
cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
alpha2 = math.acos(cosalpha2)
N2 = 4 * (n2**2 + m2*n2 + m2**2)/3
print('alpha=',np.degrees(alpha2),'N=',N2)
# Out:
# alpha= 38.21321070173819 N= 28.0

# %%
m3 = 26
n3 = 19
cosalpha3 = (n3**2 + 4*m3*n3 + m3**2) / (2*(n3**2 + m3*n3 + m3**2))
alpha3 = math.acos(cosalpha3)
N3 = 4 * (n3**2 + m3*n3 + m3**2)
print('alpha=',np.degrees(alpha3),'N=',N3)
# Out:
# alpha= 10.263936052860963 N= 6124

# %%
m4 = 64
n4 = 7
cosalpha4 = (n4**2 + 4*m4*n4 + m4**2) / (2*(n4**2 + m4*n4 + m4**2))
alpha4 = math.acos(cosalpha4)
N4 = 4 * (n4**2 + m4*n4 + m4**2)/3
print('alpha=',np.degrees(alpha4),'N=',N4)
# Out:
# alpha= 49.73606394713903 N= 6124.0

# %%
m5 = 29
n5 = 28
cosalpha5 = (n5**2 + 4*m5*n5 + m5**2) / (2*(n5**2 + m5*n5 + m5**2))
alpha5 = math.acos(cosalpha5)
N5 = 4 * (n5**2 + m5*n5 + m5**2)
print('alpha=',np.degrees(alpha5),'N=',N5)
# Out:
# alpha= 1.1606527198522039 N= 9748

# %%
m6 = 85
n6 = 1
cosalpha6 = (n6**2 + 4*m6*n6 + m6**2) / (2*(n6**2 + m6*n6 + m6**2))
alpha6 = math.acos(cosalpha6)
N6 = 4 * (n6**2 + m6*n6 + m6**2)/3
print('alpha=',np.degrees(alpha6),'N=',N6)
# Out:
# alpha= 58.839347280147805 N= 9748.0

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

fig, ax = plt.subplots(figsize=(6.0, 4.0))

for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)
                    ax.scatter(np.degrees(alpha), N, s=3, label=f'{m},{n}',color = 'blue')
                    ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='blue')

            elif abs_diff % 3 == 0:
                if n%3 == 0:
                    continue
                if m % 2 == 0:
                    max_n = 19 - (m - 52) // 2
                else:
                    max_n = 18 - (m - 51) // 2

                max_n = max(1, max_n)

                if n in range(0, max_n + 1):
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2) / 3
                    if N < 11000:
                        ax.scatter(np.degrees(alpha), N, s=3, label=f'{m},{n}',color = 'orange')
                        ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='red')


ax.scatter(np.degrees(alpha1),N1, marker='x', s = 50, color = 'red')#ax.legend()
ax.scatter(np.degrees(alpha2),N2, marker='x', s = 50, color = 'red')#ax.legend()
ax.scatter(np.degrees(alpha3),N3, marker='x', s = 50, color = 'green')#ax.legend()
ax.scatter(np.degrees(alpha4),N4, marker='x', s = 50, color = 'green')#ax.legend()
ax.scatter(np.degrees(alpha5),N5, marker='x', s = 50, color = 'k')#ax.legend()
ax.scatter(np.degrees(alpha6),N6, marker='x', s = 50, color = 'k')#ax.legend()
ax.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

plt.show()
#fig.savefig('odd AND even with numbers non primitive.pdf')

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

fig, ax = plt.subplots(figsize=(6.0, 4.0))

# Initialize lists to store data for legend
legend_labels = []
legend_handles = []

# Initialize flags for even and odd legends
even_legend_added = False
odd_legend_added = False

for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)
                    ax.scatter(np.degrees(alpha), N, s=2, label=f'{m},{n}', color='blue')
                    ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='blue')
                    # Add to legend lists only if not added yet
                    if not odd_legend_added:
                        legend_labels.append('SE odd')
                        legend_handles.append(plt.scatter([], [], s=3, color='blue'))
                        odd_legend_added = True

            elif abs_diff % 3 == 0:
                if n % 3 == 0:
                    continue
                if m % 2 == 0:
                    max_n = 19 - (m - 52) // 2
                else:
                    max_n = 18 - (m - 51) // 2

                max_n = max(1, max_n)

                if n in range(0, max_n + 1):
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2) / 3
                    if N < 11000:
                        ax.scatter(np.degrees(alpha), N, s=2, label=f'{m},{n}', color='orange')
                        ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='red')
                        # Add to legend lists only if not added yet
                        if not even_legend_added:
                            legend_labels.append('SE even')
                            legend_handles.append(plt.scatter([], [], s=3, color='orange'))
                            even_legend_added = True

ax.scatter(np.degrees(alpha1),N1, marker='x', s = 25, color = 'red')#ax.legend()
ax.scatter(np.degrees(alpha2),N2, marker='x', s = 25, color = 'red')#ax.legend()
ax.scatter(np.degrees(alpha3),N3, marker='x', s = 25, color = 'green')#ax.legend()
ax.scatter(np.degrees(alpha4),N4, marker='x', s = 25, color = 'green')#ax.legend()
ax.scatter(np.degrees(alpha5),N5, marker='x', s = 25, color = 'k')#ax.legend()
ax.scatter(np.degrees(alpha6),N6, marker='x', s = 25, color = 'k')#ax.legend()

# Add x markers to legend lists
legend_labels.extend(['(2,1) and (4,1) partners', '(26,19) and (64,7) partners', '(29,28) and (85,1) partners'])
legend_handles.extend([
    plt.scatter([], [], marker='x', s=10, color='red'),
    plt.scatter([], [], marker='x', s=10, color='green'),
    plt.scatter([], [], marker='x', s=10, color='k')
])

# Move the legend outside and to the right, increase spacing between legend elements
ax.legend(legend_handles, legend_labels, fontsize=6, markerscale=2, bbox_to_anchor=(1.05, 0.6), loc='upper left', borderaxespad=0., handletextpad=1.5)

# Add axis labels
ax.set_xlabel('Rotation angle', fontsize=8)
ax.set_ylabel('Number of atoms per unit cell', fontsize=8)


#plt.show()
plt.savefig('figure1.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

fig, ax = plt.subplots(figsize=(7, 4))
even_legend_added = False
odd_legend_added = False
legend_labels = []
legend_handles = []

for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)
                    ax.scatter(np.degrees(alpha), N, s=1, label=f'{m},{n}', color='blue')
                    # ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='blue')
                    if not odd_legend_added:
                        legend_labels.append('SE odd')
                        legend_handles.append(plt.scatter([], [], s=3, color='blue'))
                        odd_legend_added = True

            elif abs_diff % 3 == 0:
                if n % 3 == 0:
                    continue
                if m % 2 == 0:
                    max_n = 19 - (m - 52) // 2
                else:
                    max_n = 18 - (m - 51) // 2

                max_n = max(1, max_n)

                if n in range(0, max_n + 1):
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2) / 3
                    if N < 11000:
                        ax.scatter(np.degrees(alpha), N, s=1, label=f'{m},{n}', color='orange')
                        # ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='red')
                        if not even_legend_added:
                            legend_labels.append('SE even')
                            legend_handles.append(plt.scatter([], [], s=3, color='orange'))
                            even_legend_added = True

# Scatter plot points from nm_list with a different color
nm_list = [(s + 1, s) for s in range(1, 90)] + [(s + 1, 1) for s in range(3, 90, 3)]

for nm_pair in nm_list:
    m, n = nm_pair
    if m > n:
        abs_diff = abs(m - n)
        if abs_diff % 3 != 0:
            if n < 31 and m < 31:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                
                ax.scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}', color='k')  # Use a different color
                #ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='k')

        elif abs_diff % 3 == 0:
            if n % 3 == 0:
                continue
            if m % 2 == 0:
                max_n = 19 - (m - 52) // 2
            else:
                max_n = 18 - (m - 51) // 2

            max_n = max(1, max_n)

            if n in range(0, max_n + 1):
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2) / 3
                if N < 11000:
                    ax.scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}', color='k')  # Use a different color
                    #ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='k')
ax.set_xticks([0, 10, 20, 30, 40, 50, 60])

ax.legend(legend_handles + [plt.scatter([], [], s=5, color='k')], legend_labels + ['Moire'], fontsize=6, markerscale=2,
          bbox_to_anchor=(1.05, 0.6), loc='upper left', borderaxespad=0., handletextpad=1.5)
ax.set_xlabel('Rotation angle', fontsize=8)
ax.set_ylabel('Number of atoms per unit cell', fontsize=8)

#plt.show()
plt.savefig('figure2.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

fig, ax = plt.subplots(figsize=(7, 4))

for m in range(0, 201):
    for n in range(1, 201):
        if m > n and math.gcd(m, n) == 1:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)
                    ax.scatter(np.degrees(alpha), N, s=1, label=f'{m},{n}',color = 'blue')
                   # ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='blue')

            elif abs_diff % 3 == 0:
                if n%3 == 0:
                    continue
                if m % 2 == 0:
                    max_n = 19 - (m - 52) // 2
                else:
                    max_n = 18 - (m - 51) // 2

                max_n = max(1, max_n)

                if n in range(0, max_n + 1):
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2) / 3
                    if N < 11000:
                        ax.scatter(np.degrees(alpha), N, s=1, label=f'{m},{n}',color = 'orange')
                       # ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='red')
ax.set_xticks([0, 10, 20, 30, 40, 50, 60])
ax.set_xlabel('Rotation angle', fontsize=8)
ax.set_ylabel('Number of atoms per unit cell', fontsize=8)
#plt.show()
plt.savefig('figure3.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Only odd graph with numbers

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

fig, ax = plt.subplots(figsize=(7, 4))

for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)
                    ax.scatter(np.degrees(alpha), N, s=2, label=f'{m},{n}',color = 'blue')
                    ax.text(np.degrees(alpha), N, f'{m},{n}', fontsize=3, ha='right', va='bottom', color='blue')


ax.set_xticks([0, 10, 20, 30, 40, 50, 60])
ax.set_xlabel('Rotation angle', fontsize=8)
ax.set_ylabel('Number of atoms per unit cell', fontsize=8)

#plt.show()
plt.savefig('figure4.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.lines import Line2D

fig, ax = plt.subplots(figsize=(11, 7))

# Create dictionaries to store points for each m value
points_by_m = {}

for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)

                    # Check if the dictionary for this 'm' value exists
                    if m not in points_by_m:
                        points_by_m[m] = {'alphas': [], 'N_values': []}

                    # Add the data points to the dictionary
                    points_by_m[m]['alphas'].append(np.degrees(alpha))
                    points_by_m[m]['N_values'].append(N)

# Plot curves for each 'm' value
for m, data in points_by_m.items():
    ax.scatter(data['alphas'], data['N_values'], s=10, label=f'm={m}')
    line = ax.plot(data['alphas'], data['N_values'], label=f'm={m}', alpha=0.5)[0]

# Add a single arrow annotation
arrow_index = len(data['alphas']) // 2  # Change this to adjust arrow position
ax.annotate('', xy=(data['alphas'][arrow_index], data['N_values'][arrow_index]),
            xytext=(data['alphas'][arrow_index - 1], data['N_values'][arrow_index - 1]),
            arrowprops=dict(arrowstyle='->', color=line.get_color(), lw=1))

# Add a text annotation with LaTeX symbol right above the arrow
ax.text(data['alphas'][arrow_index], data['N_values'][arrow_index] + 300, r'$n \uparrow$ ',
        color=line.get_color(), ha='center', va='bottom', fontsize=10)

# Customize plot if needed
plt.xlabel('Alpha (degrees)')
plt.ylabel('N')
plt.title('Curves for Different m Values')

ax.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

# Create custom legend handles for the lines
line_handles = [Line2D([0], [0], color=line.get_color(), label=line.get_label()) for line in ax.lines if
                int(line.get_label().split('=')[1]) <= 88]

# Create the legend with custom handles
legend = ax.legend(handles=line_handles, loc='upper left', bbox_to_anchor=(1, 1), ncol=2)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.lines import Line2D

fig, ax = plt.subplots(figsize=(11, 7))

# Create dictionaries to store points for each m value
points_by_m = {}

for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)

                    # Check if the dictionary for this 'm' value exists
                    if m not in points_by_m:
                        points_by_m[m] = {'alphas': [], 'N_values': []}

                    # Add the data points to the dictionary
                    points_by_m[m]['alphas'].append(np.degrees(alpha))
                    points_by_m[m]['N_values'].append(N)

# Plot curves for each 'm' value
for m, data in points_by_m.items():
    ax.scatter(data['alphas'], data['N_values'], s=10, label=f'm={m}')
    line = ax.plot(data['alphas'], data['N_values'], label=f'm={m}', alpha=0.5)[0]

# Add a single arrow annotation
arrow_index = len(data['alphas']) // 2  # Change this to adjust arrow position
ax.annotate('', xy=(data['alphas'][arrow_index], data['N_values'][arrow_index]),
            xytext=(data['alphas'][arrow_index - 1], data['N_values'][arrow_index - 1]),
            arrowprops=dict(arrowstyle='->', color=line.get_color(), lw=1))

# Add a text annotation with LaTeX symbol right above the arrow
ax.text(data['alphas'][arrow_index], data['N_values'][arrow_index] + 300, r'$n \uparrow$ ',
        color=line.get_color(), ha='center', va='bottom', fontsize=10)

# Customize plot if needed
plt.xlabel('Alpha (degrees)')
plt.ylabel('N')
plt.title('Curves for Different m Values')

ax.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

# Create custom legend handles for the lines
line_handles = [Line2D([0], [0], color=line.get_color(), label=line.get_label()) for line in ax.lines if
                int(line.get_label().split('=')[1]) <= 88]

# Create the legend with custom handles
legend = ax.legend(handles=line_handles, loc='upper left', bbox_to_anchor=(1, 1), ncol=2)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.lines import Line2D

fig, ax = plt.subplots(figsize=(11, 7))

# Create dictionaries to store points for each m value
points_by_n = {}

for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)

                    # Check if the dictionary for this 'm' value exists
                    if n not in points_by_n:
                        points_by_n[n] = {'alphas': [], 'N_values': []}

                    # Add the data points to the dictionary
                    points_by_n[n]['alphas'].append(np.degrees(alpha))
                    points_by_n[n]['N_values'].append(N)

# Plot curves for each 'm' value
for n, data in points_by_n.items():
    ax.scatter(data['alphas'], data['N_values'], s=5, label=f'n={n}')
    line = ax.plot(data['alphas'], data['N_values'], label=f'n={n}', alpha=0.8)[0]

    # Add arrow indicating the direction of increasing 'm'
    arrow_index = len(data['alphas']) // 2  # Change this to adjust arrow position
    ax.annotate('', xy=(data['alphas'][arrow_index], data['N_values'][arrow_index]),
                xytext=(data['alphas'][arrow_index - 1], data['N_values'][arrow_index - 1]),
                arrowprops=dict(arrowstyle='->', color=line.get_color(), lw=1))

    # Add a text annotation
    if n % 10 == 0:  # Add 'm ↑' on top of one arrow
        ax.text(data['alphas'][arrow_index], data['N_values'][arrow_index] + 100, r'$m \uparrow$', 
                color=line.get_color(), ha='center', va='bottom', fontsize=8)

# Customize plot if needed
plt.xlabel('Alpha (degrees)')
plt.ylabel('N')
plt.title('Curves for Different n Values')

ax.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

# Create custom legend handles for the lines
line_handles = [Line2D([0], [0], color=line.get_color(), label=line.get_label()) for line in ax.lines if
                int(line.get_label().split('=')[1]) <= 30]

# Create the legend with custom handles
legend = ax.legend(handles=line_handles, loc='upper left', bbox_to_anchor=(1, 1), ncol=2)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.lines import Line2D

# Create subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(24, 7))  # Two subplots stacked vertically


# Create dictionaries to store points for each m value
points_by_m = {}
points_by_n = {}

# Plot for the first graph
for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)

                    # Check if the dictionary for this 'm' value exists
                    if m not in points_by_m:
                        points_by_m[m] = {'alphas': [], 'N_values': []}

                    # Add the data points to the dictionary
                    points_by_m[m]['alphas'].append(np.degrees(alpha))
                    points_by_m[m]['N_values'].append(N)

# Plot curves for each 'm' value
for m, data in points_by_m.items():
    ax1.scatter(data['alphas'], data['N_values'], s=5, label=f'm={m}')
    line = ax1.plot(data['alphas'], data['N_values'], label=f'm={m}', alpha=0.5, lw = 1.5)[0]

# Add a single arrow annotation
arrow_index = len(data['alphas']) // 2  # Change this to adjust arrow position
ax1.annotate('', xy=(data['alphas'][arrow_index], data['N_values'][arrow_index]),
            xytext=(data['alphas'][arrow_index - 1], data['N_values'][arrow_index - 1]),
            arrowprops=dict(arrowstyle='->', color=line.get_color(), lw = 1.5))

# Add a text annotation with LaTeX symbol right above the arrow
ax1.text(data['alphas'][arrow_index], data['N_values'][arrow_index] + 300, r'$n \uparrow$ ',
        color=line.get_color(), ha='center', va='bottom', fontsize=10)

# Customize plot if needed
ax1.set_xlabel('Rotation angle', fontsize=8)
ax1.set_ylabel('N', fontsize=8)
ax1.set_title('a', loc='left')

# Create custom legend handles for the lines
line_handles_m = [Line2D([0], [0], color=line.get_color(), label=line.get_label()) for line in ax1.lines if
                int(line.get_label().split('=')[1]) <= 88]

# Create the legend with custom handles
legend_m = ax1.legend(handles=line_handles_m, loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=6, fontsize = 15)

# Plot for the second graph
for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)

                    # Check if the dictionary for this 'm' value exists
                    if n not in points_by_n:
                        points_by_n[n] = {'alphas': [], 'N_values': []}

                    # Add the data points to the dictionary
                    points_by_n[n]['alphas'].append(np.degrees(alpha))
                    points_by_n[n]['N_values'].append(N)

# Plot curves for each 'm' value
for n, data in points_by_n.items():
    ax2.scatter(data['alphas'], data['N_values'], s=5.5, label=f'n={n}')
    line = ax2.plot(data['alphas'], data['N_values'], label=f'n={n}', alpha=0.8, lw = 1.5)[0]

    # Add arrow indicating the direction of increasing 'm'
    arrow_index = len(data['alphas']) // 2  # Change this to adjust arrow position
    ax2.annotate('', xy=(data['alphas'][arrow_index], data['N_values'][arrow_index]),
                xytext=(data['alphas'][arrow_index - 1], data['N_values'][arrow_index - 1]),
                arrowprops=dict(arrowstyle='->', color=line.get_color(), lw = 1.5))

    # Add a text annotation
    if n % 10 == 0:  # Add 'm ↑' on top of one arrow
        ax2.text(data['alphas'][arrow_index], data['N_values'][arrow_index] + 100, r'$m \uparrow$', 
                color=line.get_color(), ha='center', va='bottom', fontsize=8)

# Customize plot if needed
ax2.set_xlabel('Rotation angle', fontsize=8)
ax2.set_ylabel('N', fontsize=8)
ax2.set_title('b', loc='left')

ax2.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

# Create custom legend handles for the lines
line_handles_n = [Line2D([0], [0], color=line.get_color(), label=line.get_label()) for line in ax2.lines if
                int(line.get_label().split('=')[1]) <= 30]

# Create the legend with custom handles
legend_n = ax2.legend(handles=line_handles_n, loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=6, fontsize = 15)
ax1.set_xticks([0, 10, 20, 30, 40, 50, 60])    
ax2.set_xticks([0, 10, 20, 30, 40, 50, 60])
ax1.tick_params(axis='both', which='both', labelsize=8)
ax2.tick_params(axis='both', which='both', labelsize=8)
# Adjust layout to prevent clipping of labels
#plt.tight_layout()
#plt.tight_layout()

# Show the plot
#plt.show()
plt.savefig('figure5.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.lines import Line2D

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 6.5))  # Two subplots stacked vertically

# Create dictionaries to store points for each m value
points_by_m = {}
points_by_n = {}

# Plot for the first graph
for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)

                    # Check if the dictionary for this 'm' value exists
                    if m not in points_by_m:
                        points_by_m[m] = {'alphas': [], 'N_values': []}

                    # Add the data points to the dictionary
                    points_by_m[m]['alphas'].append(np.degrees(alpha))
                    points_by_m[m]['N_values'].append(N)

# Plot curves for each 'm' value
for m, data in points_by_m.items():
    ax1.scatter(data['alphas'], data['N_values'], s=1, label=f'm={m}')
    line = ax1.plot(data['alphas'], data['N_values'], label=f'm={m}', alpha=0.5, lw=0.8)[0]

# Add a single arrow annotation
arrow_index = len(data['alphas']) // 2  # Change this to adjust arrow position
ax1.annotate('', xy=(data['alphas'][arrow_index], data['N_values'][arrow_index]),
            xytext=(data['alphas'][arrow_index - 1], data['N_values'][arrow_index - 1]),
            arrowprops=dict(arrowstyle='->', color=line.get_color(), lw=1))

# Add a text annotation with LaTeX symbol right above the arrow
ax1.text(data['alphas'][arrow_index], data['N_values'][arrow_index] + 300, r'$n \uparrow$ ',
        color=line.get_color(), ha='center', va='bottom', fontsize=10, weight='bold')

# Customize plot if needed
ax1.set_xlabel('Rotation angle', fontsize=8)
ax1.set_ylabel('# of atoms per unit cell', fontsize=8)
ax1.set_title('a', loc='left')

# Create custom legend handles for the lines
line_handles_m = [Line2D([0], [0], color=line.get_color(), label=line.get_label()) for line in ax1.lines if
                int(line.get_label().split('=')[1]) <= 88]

# Create the legend with custom handles
legend_m = ax1.legend(handles=line_handles_m, loc='upper left', bbox_to_anchor=(1, 1), ncol=2, fontsize = 6)

# Plot for the second graph
for m in range(0, 201):
    for n in range(1, 201):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)

                    # Check if the dictionary for this 'm' value exists
                    if n not in points_by_n:
                        points_by_n[n] = {'alphas': [], 'N_values': []}

                    # Add the data points to the dictionary
                    points_by_n[n]['alphas'].append(np.degrees(alpha))
                    points_by_n[n]['N_values'].append(N)

# Plot curves for each 'm' value
for n, data in points_by_n.items():
    ax2.scatter(data['alphas'], data['N_values'], s=1.5, label=f'n={n}')
    line = ax2.plot(data['alphas'], data['N_values'], label=f'n={n}', alpha=0.8, lw=0.8)[0]

    # Add arrow indicating the direction of increasing 'm'
    arrow_index = len(data['alphas']) // 2  # Change this to adjust arrow position
    ax2.annotate('', xy=(data['alphas'][arrow_index], data['N_values'][arrow_index]),
                xytext=(data['alphas'][arrow_index - 1], data['N_values'][arrow_index - 1]),
                arrowprops=dict(arrowstyle='->', color=line.get_color(), lw=1))

    # Add a text annotation
    if n % 10 == 0:  # Add 'm ↑' on top of one arrow
        ax2.text(data['alphas'][arrow_index], data['N_values'][arrow_index] + 100, r'$m \uparrow$', 
                color=line.get_color(), ha='center', va='bottom', fontsize=8, weight='bold')

# Customize plot if needed
ax2.set_xlabel('Rotation angle', fontsize=8)
ax2.set_ylabel('# of atoms per unit cell', fontsize=8)
ax2.set_title('b', loc='left')

ax2.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

# Create custom legend handles for the lines
line_handles_n = [Line2D([0], [0], color=line.get_color(), label=line.get_label()) for line in ax2.lines if
                int(line.get_label().split('=')[1]) <= 30]

# Create the legend with custom handles
legend_n = ax2.legend(handles=line_handles_n, loc='upper left', bbox_to_anchor=(1, 1), ncol=2, fontsize = 6)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Show the plot
#plt.show()
plt.savefig('figure5.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

fig, ax = plt.subplots(figsize=(7, 4))

# Dictionary to store colors for each abs_diff value
abs_diff_colors = {}

# Dictionary to store points for each abs_diff value
abs_diff_points = {}
handles = []
for m in range(0, 201):
    for n in range(1, 201):
        if m > n :
            abs_diff = abs(m - n)

            # Check if a color is assigned for this abs_diff value
            if abs_diff not in abs_diff_colors:
                # Assign a new darkened color if not already assigned
                base_color = np.random.rand(3)
                darkened_color = tuple(c * 0.7 for c in base_color)
                abs_diff_colors[abs_diff] = darkened_color

                # Initialize the list of points for this abs_diff value
                abs_diff_points[abs_diff] = []

            color = abs_diff_colors[abs_diff]

            if abs_diff % 3 != 0:
                if n < 31 and m < 31:
                    cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                    alpha = math.acos(cosalpha)
                    N = 4 * (n**2 + m*n + m**2)
                    ax.scatter(np.degrees(alpha), N, s=1, color=color)
                    abs_diff_points[abs_diff].append((np.degrees(alpha), N))

# Plot curves connecting points with the same abs_diff value
for abs_diff, points_list in abs_diff_points.items():
    if len(points_list) > 1 and abs_diff <= 87:
        points_list = sorted(points_list, key=lambda x: x[0])
        x_values, y_values = zip(*points_list)
        color = abs_diff_colors[abs_diff]  # Use the correct color variable
        ax.plot(x_values, y_values, color=color, linestyle='-', linewidth=0.5, label=f'|m-n|={abs_diff}')
        handles.append(plt.Line2D([0], [0], color=color, label=f'|m-n|={abs_diff}'))
        # Add arrow indicating the direction of increasing 'm' and 'n' for a specific abs_diff value
        arrow_index = len(points_list) // 2  # Change this to adjust arrow position
        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                    arrowprops=dict(arrowstyle='->', color=color, lw=1))

        if abs_diff == 1:
            ax.annotate(r'$\downarrow$m,$\downarrow$n', xy=(x_values[arrow_index], y_values[arrow_index]),
                        xytext=(x_values[arrow_index]-2.8 , y_values[arrow_index] - 100),
                        ha='center', va='center', color=color, fontsize=5, weight='bold')


# Manually create a custom horizontal legend with two colors next to each other
legend = ax.legend(handles=handles, loc='upper left', bbox_to_anchor=(1, 1.03), ncol=1, fontsize=5)

ax.set_xticks([0, 10, 20, 30, 40, 50, 60])    
ax.set_xlabel('Rotation angle', fontsize=8)
ax.set_ylabel('Number of atoms per unit cell', fontsize=8)


#plt.show()
plt.savefig('figure6.png', dpi=300, bbox_inches='tight')

# %%
orange_points = set()

# %%
fig, ax = plt.subplots(figsize=(11, 7))



for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                ax.scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list =  [(s + 1, 1) for s in range(1, 30)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        ax.scatter(point_to_plot[0], point_to_plot[1], s=5, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 1
                                    n2 = n2 + 1

                        ax.plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.2)
                        # Add arrow indicating the direction of increasing 'm' and 'n' for a specific abs_diff value
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=1))

                        if abs_diff == 1:
                            ax.annotate(r' m+1, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 5, y_values[arrow_index] - 100),
                                        ha='left', va='bottom', color=color, fontsize=8)


plt.show()

# %%
fig, ax = plt.subplots(figsize=(11, 7))



for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                ax.scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list =  [(s + 1, 1) for s in range(1, 30)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        ax.scatter(point_to_plot[0], point_to_plot[1], s=5, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 1
                                    n2 = n2 + 1

                        ax.plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.2)

                        
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=1))

                        if abs_diff == 1:
                            ax.annotate(r' m+1, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 5, y_values[arrow_index] - 100),
                                        ha='left', va='bottom', color=color, fontsize=8)

ax.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

plt.show()

# %%
fig, ax = plt.subplots(figsize=(11, 7))



for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                ax.scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list =  [(s + 1, s) for s in range(1, 30)]+ [(s + 2 , s) for s in range(1, 30)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        ax.scatter(point_to_plot[0], point_to_plot[1], s=5, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 1
                                    n2 = n2 - 1

                        ax.plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.2)
                        # Add arrow indicating the direction of increasing 'm' and 'n' for a specific abs_diff value
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=1))

                        if m == 26:
                            ax.annotate(r' m+1, n-1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=8, weight='bold')

                            
ax.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

plt.show()

# %%
fig, ax = plt.subplots(figsize=(11, 7))



for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                ax.scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list =  [(s + 1, s) for s in range(1, 30)]+ [(s + 2 , s) for s in range(1, 30)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        ax.scatter(point_to_plot[0], point_to_plot[1], s=5, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 1
                                    n2 = n2 - 2

                        ax.plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.2)

                        
                        # Add arrow indicating the direction of increasing 'm' and 'n' for a specific abs_diff value
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=1))

                        if m == 26:
                            ax.annotate(r' m+1, n-2', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=8, weight='bold')

                            
ax.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

plt.show()

# %%
fig, ax = plt.subplots(figsize=(11, 7))



for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                ax.scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list =  [(s + 1, s) for s in range(1, 30)]+ [(s + 2 , s) for s in range(1, 30)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        ax.scatter(point_to_plot[0], point_to_plot[1], s=5, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 2
                                    n2 = n2 - 1

                        ax.plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.2)

                        
                    
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=1))

                        if m == 26:
                            ax.annotate(r' m+2, n-1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=8, weight='bold')

                            
ax.set_ylim(bottom=0, top=11000)  # Adjust the values according to your requirements

plt.show()

# %%
orange_points= set()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from itertools import cycle, islice

# Create a figure with subplots
fig, axs = plt.subplots(2, 2, figsize=(210 / 25.4, 148.5 / 25.4))

# Flatten the axs array for easy indexing
axs = axs.flatten()


# Case 1
for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                #axs[0].scatter(np.degrees(alpha), N, s=2, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list =  [(s + 1, 1) for s in range(1, 30)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        axs[0].scatter(point_to_plot[0], point_to_plot[1], s=2, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 1
                                    n2 = n2 + 1

                        axs[0].plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.2)

                        
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        axs[0].annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=1))

                        if abs_diff == 1:
                            axs[0].annotate(r' m+1, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 7, y_values[arrow_index] - 100),
                                        ha='left', va='bottom', color=color, fontsize=5, weight='bold')

# Case 2
for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)

                #axs[1].scatter(np.degrees(alpha), N, s=2, label=f'{m},{n}', color='blue', alpha=0.2)

                orange_points.add((np.degrees(alpha), N))

                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 2, s) for s in range(1, 30)]

                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow',
                                            'magenta', 'k', 'azure', 'chocolate', 'darkblue', 'darkcyan', 'darksalmon',
                                            'indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2)
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        axs[1].scatter(point_to_plot[0], point_to_plot[1], s=2, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 1
                                    n2 = n2 - 1

                        axs[1].plot(x_values, y_values, label=f'{m},{n}', color='grey', alpha=0.2)
                        # Add arrow indicating the direction of increasing 'm' and 'n' for a specific abs_diff value
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        axs[1].annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                        arrowprops=dict(arrowstyle='->', color=color, lw=0.2))

                        if m == 26:
                            axs[1].annotate(r' m+1, n-1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                            xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                            ha='center', va='center', color=color, fontsize=5, weight='bold')

# Case 3
for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)

                #axs[2].scatter(np.degrees(alpha), N, s=2, label=f'{m},{n}', color='blue', alpha=0.2)

                orange_points.add((np.degrees(alpha), N))

                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 2, s) for s in range(1, 30)]

                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow',
                                            'magenta', 'k', 'azure', 'chocolate', 'darkblue', 'darkcyan', 'darksalmon',
                                            'indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2)
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        axs[2].scatter(point_to_plot[0], point_to_plot[1], s=2, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 2
                                    n2 = n2 - 1

                        axs[2].plot(x_values, y_values, label=f'{m},{n}', color='grey', alpha=0.2)
                        # Add arrow indicating the direction of increasing 'm' and 'n' for a specific abs_diff value
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        axs[2].annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index ]-3, y_values[arrow_index - 1]),
                                        arrowprops=dict(arrowstyle='->', color=color, lw=0.2))

                        if m == 26:
                            axs[2].annotate(r' m+2, n-1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                            xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                            ha='center', va='center', color=color, fontsize=5, weight='bold')

# Case 4
for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)

                #axs[3].scatter(np.degrees(alpha), N, s=2, label=f'{m},{n}', color='blue', alpha=0.2)

                orange_points.add((np.degrees(alpha), N))

                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 2, s) for s in range(1, 30)]

                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow',
                                            'magenta', 'k', 'azure', 'chocolate', 'darkblue', 'darkcyan', 'darksalmon',
                                            'indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2)
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        axs[3].scatter(point_to_plot[0], point_to_plot[1], s=2, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 1
                                    n2 = n2 - 2

                        axs[3].plot(x_values, y_values, label=f'{m},{n}', color='grey', alpha=0.2)
                        # Add arrow indicating the direction of increasing 'm' and 'n' for a specific abs_diff value
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        axs[3].annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index ]-3, y_values[arrow_index - 1]),
                                        arrowprops=dict(arrowstyle='->', color=color, lw=0.2))

                        if m == 26:
                            axs[3].annotate(r' m+1, n-2', xy=(x_values[arrow_index], y_values[arrow_index]),
                                            xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                            ha='center', va='center', color=color, fontsize=5, weight='bold')


axs[0].set_xlabel('Rotation angle', fontsize=8)
axs[0].set_ylabel('Number of atoms per unit cell', fontsize=8)
axs[0].yaxis.set_label_coords(-0.15, 0.5)
axs[0].set_title('a', loc='left')                           
axs[1].set_xlabel('Rotation angle', fontsize=8)
axs[1].set_ylabel('Number of atoms per unit cell', fontsize=8)
axs[1].yaxis.set_label_coords(-0.15, 0.5)
axs[1].set_title('b', loc='left')                           
axs[2].set_xlabel('Rotation angle', fontsize=8)
axs[2].set_ylabel('Number of atoms per unit cell', fontsize=8)
axs[2].yaxis.set_label_coords(-0.15, 0.5)
axs[2].set_title('c', loc='left')
axs[3].set_xlabel('Rotation angle', fontsize=8)
axs[3].set_ylabel('Number of atoms per unit cell', fontsize=8)
axs[3].set_title('d', loc='left')
axs[3].yaxis.set_label_coords(-0.15, 0.5)
# Adjust layout
plt.tight_layout(h_pad=1.1, w_pad=1.5)

#plt.show()
plt.savefig('figure7.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3.0, 2.5))



for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                #ax.scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 1, 1) for s in range(1, 30)] + [(s , 2) for s in range(6, 30, 3)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        ax.scatter(point_to_plot[0], point_to_plot[1], s=1, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 2
                                    n2 = n2 + 1

                        ax.plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.4, lw = 0.8)

                        
                        
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=0.5))

                        if m == 26:
                            ax.annotate(r' m+2, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=5, weight='bold')

ax.set_xticks([0, 10, 20, 30, 40, 50, 60])                           
ax.set_xlabel('Rotation angle', fontsize=8)
ax.set_ylabel('Number of atoms per unit cell', fontsize=8)


#plt.show()
plt.savefig('figure8.png', dpi=300, bbox_inches='tight')

# %%
m = 2
n = 1
cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
alpha = math.acos(cosalpha)
np.degrees(alpha)
# Out:
# 21.78678929826181

# %%
fig, ax = plt.subplots(figsize=(3.0, 2.5))



for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                #ax.scatter(np.degrees(alpha), N, s=1, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 1, 1) for s in range(0, 30)] + [(s + 3, s+1) for s in range(0, 30)]  
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        ax.scatter(point_to_plot[0], point_to_plot[1], s=1, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 4
                                    n2 = n2 + 1

                        ax.plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.4, lw = 0.8)

                        
                        
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=0.5,alpha = 0.5))

                        if m == 26:
                            ax.annotate(r' m+4, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=5, weight='bold')

ax.set_xticks([0, 10, 20, 30, 40, 50, 60])                     
ax.set_xlabel('Rotation angle', fontsize=8)
ax.set_ylabel('Number of atoms per unit cell', fontsize=8)


#plt.show()
plt.savefig('figure9.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Number of atoms per unit cell')

# %%
fig, ax = plt.subplots(figsize=(3.0, 2.5))



for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                #ax.scatter(np.degrees(alpha), N, s=1, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 1, 1) for s in range(0, 30)] + [(s + 3, s+1) for s in range(0, 30)] + [(s , 2) for s in range(7, 30, 3)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        ax.scatter(point_to_plot[0], point_to_plot[1], s=1, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 3
                                    n2 = n2 + 1

                        ax.plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.4, lw = 0.8)

                        
                        
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        ax.annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=0.5,alpha = 0.5))

                        if m == 26:
                            ax.annotate(r' m+3, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=5, weight='bold')

ax.set_xticks([0, 10, 20, 30, 40, 50, 60])                     
ax.set_xlabel('Rotation angle', fontsize=8)
ax.set_ylabel('Number of atoms per unit cell', fontsize=8)


#plt.show()
plt.savefig('figure10.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from itertools import cycle, islice

# Create a figure with subplots
fig, axs = plt.subplots(2, 2, figsize=(11.0, 7.5))

# Remove the empty fourth subplot
fig.delaxes(axs[1, 1])

# Flatten the axs array for easy indexing
axs = axs.flatten()

for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                #axs[0].scatter(np.degrees(alpha), N, s=5, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 1, 1) for s in range(1, 30)] + [(s , 2) for s in range(6, 30, 3)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        axs[0].scatter(point_to_plot[0], point_to_plot[1], s=1, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 2
                                    n2 = n2 + 1

                        axs[0].plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.4, lw = 0.8)

                        
                        
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        axs[0].annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=0.5))

                        if m == 26:
                            axs[0].annotate(r' m+2, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=5, weight='bold')

                            
                            
for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                #axs[1].scatter(np.degrees(alpha), N, s=1, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 1, 1) for s in range(0, 30)] + [(s + 3, s+1) for s in range(0, 30)]  
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        axs[1].scatter(point_to_plot[0], point_to_plot[1], s=1, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 4
                                    n2 = n2 + 1

                        axs[1].plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.4, lw = 0.8)

                        
                        
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        axs[1].annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=0.5,alpha = 0.5))

                        if m == 26:
                            axs[1].annotate(r' m+4, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=5, weight='bold')




for m in range(0, 31):
    for n in range(1, 31):
        if m > n:
            abs_diff = abs(m - n)
            if abs_diff % 3 != 0:
                cosalpha = (n**2 + 4*m*n + m**2) / (2*(n**2 + m*n + m**2))
                alpha = math.acos(cosalpha)
                N = 4 * (n**2 + m*n + m**2)
                
                #axs[2].scatter(np.degrees(alpha), N, s=1, label=f'{m},{n}',color = 'blue',alpha = 0.2)
                
                orange_points.add((np.degrees(alpha), N))

                
                nm_list = [(s + 1, s) for s in range(1, 30)] + [(s + 1, 1) for s in range(0, 30)] + [(s + 3, s+1) for s in range(0, 30)] + [(s , 2) for s in range(7, 30, 3)] 
                
                
                colors = list(islice(cycle(['red', 'green', 'purple', 'brown', 'pink', 'cyan', 'gray', 'yellow', 'magenta','k','azure','chocolate','darkblue','darkcyan','darksalmon','indianred']), len(nm_list)))

                for i in range(len(nm_list)):
                    if m == nm_list[i][0] and n == nm_list[i][1]:
                        m2 = m
                        n2 = n
                        color = colors[i]
                        x_values = []
                        y_values = []

                        for m1 in range(0, 31):
                            for n1 in range(0, 31):
                                if m1 == m2 and n1 == n2:
                                    
                                    cosalpha2 = (n2**2 + 4*m2*n2 + m2**2) / (2*(n2**2 + m2*n2 + m2**2))
                                    alpha2 = math.acos(cosalpha2)
                                    N2 = 4 * (n2**2 + m2*n2 + m2**2) 
                                    point_to_plot = (np.degrees(alpha2), N2)
                                    if point_to_plot in orange_points:
                                        axs[2].scatter(point_to_plot[0], point_to_plot[1], s=1, label=f'{m},{n}', color=color)
                                        x_values.append(point_to_plot[0])
                                        y_values.append(point_to_plot[1])
                                    m2 = m2 + 3
                                    n2 = n2 + 1

                        axs[2].plot(x_values, y_values, label=f'{m},{n}', color='grey',alpha= 0.4, lw = 0.8)

                        
                        
                        arrow_index = len(x_values) // 2  # Change this to adjust arrow position
                        axs[2].annotate('', xy=(x_values[arrow_index], y_values[arrow_index]),
                                    xytext=(x_values[arrow_index - 1], y_values[arrow_index - 1]),
                                    arrowprops=dict(arrowstyle='->', color=color, lw=0.5,alpha = 0.5))

                        if m == 26:
                            axs[2].annotate(r' m+3, n+1', xy=(x_values[arrow_index], y_values[arrow_index]),
                                        xytext=(x_values[arrow_index] - 3, y_values[arrow_index] - 300),
                                        ha='center', va='center', color=color, fontsize=5, weight='bold')

axs[2].set_xticks([0, 10, 20, 30, 40, 50, 60])                     
axs[2].set_xlabel('Rotation angle', fontsize=8)
axs[2].set_ylabel('Number of atoms per unit cell', fontsize=8)
axs[1].set_xticks([0, 10, 20, 30, 40, 50, 60])                     
axs[1].set_xlabel('Rotation angle', fontsize=8)
axs[1].set_ylabel('Number of atoms per unit cell', fontsize=8)
axs[0].set_xticks([0, 10, 20, 30, 40, 50, 60])                     
axs[0].set_xlabel('Rotation angle', fontsize=8)
axs[0].set_ylabel('Number of atoms per unit cell', fontsize=8)

                            
axs[0].yaxis.set_label_coords(-0.2, 0.5)
axs[0].set_title('a', loc='left')                           
axs[1].yaxis.set_label_coords(-0.2, 0.5)
axs[1].set_title('b', loc='left')                           
axs[2].yaxis.set_label_coords(-0.2, 0.5)
axs[2].set_title('c', loc='left')
# Adjust layout
plt.tight_layout(h_pad=1.3, w_pad=1.5)

#plt.show()
plt.savefig('Report- figure13.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Graphs for even
